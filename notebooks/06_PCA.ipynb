# %% [markdown]
# Below is a step-by-step notebook style code that demonstrates:
#
# 1️⃣ Feature Selection
# 2️⃣ Dimensionality Reduction using PCA
# 3️⃣ Creating Pipelines
# 4️⃣ Handling Class Imbalance

# %% [markdown]
# #### import important library

# %%
# %pip install -U imbalanced-learn scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# e:\MLP\.venv\Scripts\python.exe: No module named pip

# %%
# Install the package if needed (you only need to do this once)
# !pip install imbalanced-learn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.compose import ColumnTransformer
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline
